# %%
import pandas as pd

# %%
data = pd.read_csv('IMDB-Movie-Data.csv', header=0)

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.dropna(how = 'any', inplace = True)

# %%
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# # Question 1. Which year made the most revenue

# %%
data.groupby('Year') ['Revenue (Millions)'].sum()
# Out:
# Year
# 2006     3577.48
# 2007     4095.26
# 2008     4681.22
# 2009     5208.39
# 2010     5989.65
# 2011     5341.09
# 2012     6826.39
# 2013     7399.11
# 2014     7945.33
# 2015     8799.09
# 2016    11002.09
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# # Question 2. Directors with the lowest rated movies

# %%
lowratedmovies= imdbdata.query('(Rating > 0) & (Rating < 3.0)')
lowratedmovies [['Director','Rating']]
# Out:
#             Director  Rating
# 42     Shawn Burkett     2.7
# 829  Jason Friedberg     1.9
# 871       James Wong     2.7

# %% [markdown]
# # Question 3. Which Actors made the most revenue

# %%
Sortedrevenue = data.sort_values(['Revenue (Millions)'], ascending=False)
actorsrevenue = Sortedrevenue [['Actors','Revenue (Millions)']]
actorsrevenue.head()
# Out:
#                                                Actors  Revenue (Millions)
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...              936.63
# 87  Sam Worthington, Zoe Saldana, Sigourney Weaver...              760.51
# 85  Chris Pratt, Bryce Dallas Howard, Ty Simpkins,...              652.18
# 76  Robert Downey Jr., Chris Evans, Scarlett Johan...              623.28
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...              533.32
